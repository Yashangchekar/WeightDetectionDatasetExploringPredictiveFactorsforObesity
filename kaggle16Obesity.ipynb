# %%
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('Obesity.csv')
df
# Out:
#       Gender        Age    Height      Weight family_history_with_overweight  \
# 0     Female  21.000000  1.620000   64.000000                            yes
# 1     Female  21.000000  1.520000   56.000000                            yes
# 2       Male  23.000000  1.800000   77.000000                            yes
# 3       Male  27.000000  1.800000   87.000000                             no
# 4       Male  22.000000  1.780000   89.800000                             no
# ...      ...        ...       ...         ...                            ...
# 2106  Female  20.976842  1.710730  131.408528                            yes
# 2107  Female  21.982942  1.748584  133.742943                            yes
# 2108  Female  22.524036  1.752206  133.689352                            yes
# 2109  Female  24.361936  1.739450  133.346641                            yes
# 2110  Female  23.664709  1.738836  133.472641                            yes
#
# ...

# %%
df.dtypes
# Out:
# Gender                             object
# Age                               float64
# Height                            float64
# Weight                            float64
# family_history_with_overweight     object
# FAVC                               object
# FCVC                              float64
# NCP                               float64
# CAEC                               object
# SMOKE                              object
# CH2O                              float64
# SCC                                object
# FAF                               float64
# TUE                               float64
# CALC                               object
# MTRANS                             object
# NObeyesdad                         object
# dtype: object

# %%
df.head(5)
# Out:
#    Gender   Age  Height  Weight family_history_with_overweight FAVC  FCVC  \
# 0  Female  21.0    1.62    64.0                            yes   no   2.0
# 1  Female  21.0    1.52    56.0                            yes   no   3.0
# 2    Male  23.0    1.80    77.0                            yes   no   2.0
# 3    Male  27.0    1.80    87.0                             no   no   3.0
# 4    Male  22.0    1.78    89.8                             no   no   2.0
#
#    NCP       CAEC SMOKE  CH2O  SCC  FAF  TUE        CALC  \
# 0  3.0  Sometimes    no   2.0   no  0.0  1.0          no
# 1  3.0  Sometimes   yes   3.0  yes  3.0  0.0   Sometimes
# 2  3.0  Sometimes    no   2.0   no  2.0  1.0  Frequently
# 3  3.0  Sometimes    no   2.0   no  2.0  0.0  Frequently
# 4  1.0  Sometimes    no   2.0   no  0.0  0.0   Sometimes
#
#                   MTRANS           NObeyesdad
# 0  Public_Transportation        Normal_Weight
# 1  Public_Transportation        Normal_Weight
# ...

# %%
df.isnull().sum()/df.shape[0]*100
# Out:
# Gender                            0.0
# Age                               0.0
# Height                            0.0
# Weight                            0.0
# family_history_with_overweight    0.0
# FAVC                              0.0
# FCVC                              0.0
# NCP                               0.0
# CAEC                              0.0
# SMOKE                             0.0
# CH2O                              0.0
# SCC                               0.0
# FAF                               0.0
# TUE                               0.0
# CALC                              0.0
# MTRANS                            0.0
# NObeyesdad                        0.0
# dtype: float64

# %%
sb.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df.duplicated().sum()
# Out:
# 24

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df_obj=df.select_dtypes(object)
df_obj
# Out:
#       Gender family_history_with_overweight FAVC       CAEC SMOKE  SCC  \
# 0     Female                            yes   no  Sometimes    no   no
# 1     Female                            yes   no  Sometimes   yes  yes
# 2       Male                            yes   no  Sometimes    no   no
# 3       Male                             no   no  Sometimes    no   no
# 4       Male                             no   no  Sometimes    no   no
# ...      ...                            ...  ...        ...   ...  ...
# 2106  Female                            yes  yes  Sometimes    no   no
# 2107  Female                            yes  yes  Sometimes    no   no
# 2108  Female                            yes  yes  Sometimes    no   no
# 2109  Female                            yes  yes  Sometimes    no   no
# 2110  Female                            yes  yes  Sometimes    no   no
#
#             CALC                 MTRANS           NObeyesdad
# ...

# %%
df_num=df.select_dtypes('float64')
df_num
# Out:
#             Age    Height      Weight  FCVC  NCP      CH2O       FAF       TUE
# 0     21.000000  1.620000   64.000000   2.0  3.0  2.000000  0.000000  1.000000
# 1     21.000000  1.520000   56.000000   3.0  3.0  3.000000  3.000000  0.000000
# 2     23.000000  1.800000   77.000000   2.0  3.0  2.000000  2.000000  1.000000
# 3     27.000000  1.800000   87.000000   3.0  3.0  2.000000  2.000000  0.000000
# 4     22.000000  1.780000   89.800000   2.0  1.0  2.000000  0.000000  0.000000
# ...         ...       ...         ...   ...  ...       ...       ...       ...
# 2106  20.976842  1.710730  131.408528   3.0  3.0  1.728139  1.676269  0.906247
# 2107  21.982942  1.748584  133.742943   3.0  3.0  2.005130  1.341390  0.599270
# 2108  22.524036  1.752206  133.689352   3.0  3.0  2.054193  1.414209  0.646288
# 2109  24.361936  1.739450  133.346641   3.0  3.0  2.852339  1.139107  0.586035
# 2110  23.664709  1.738836  133.472641   3.0  3.0  2.863513  1.026452  0.714137
#
# [2087 rows x 8 columns]

# %%
df['NObeyesdad'].value_counts()
# Out:
# Obesity_Type_I         351
# Obesity_Type_III       324
# Obesity_Type_II        297
# Overweight_Level_II    290
# Normal_Weight          282
# Overweight_Level_I     276
# Insufficient_Weight    267
# Name: NObeyesdad, dtype: int64

# %%
df_obj=df.select_dtypes(object)
df_obj
# Out:
#       Gender family_history_with_overweight FAVC       CAEC SMOKE  SCC  \
# 0     Female                            yes   no  Sometimes    no   no
# 1     Female                            yes   no  Sometimes   yes  yes
# 2       Male                            yes   no  Sometimes    no   no
# 3       Male                             no   no  Sometimes    no   no
# 4       Male                             no   no  Sometimes    no   no
# ...      ...                            ...  ...        ...   ...  ...
# 2106  Female                            yes  yes  Sometimes    no   no
# 2107  Female                            yes  yes  Sometimes    no   no
# 2108  Female                            yes  yes  Sometimes    no   no
# 2109  Female                            yes  yes  Sometimes    no   no
# 2110  Female                            yes  yes  Sometimes    no   no
#
#             CALC                 MTRANS           NObeyesdad
# ...

# %%
df_num=df.select_dtypes('float64')
df_num
# Out:
#             Age    Height      Weight  FCVC  NCP      CH2O       FAF       TUE
# 0     21.000000  1.620000   64.000000   2.0  3.0  2.000000  0.000000  1.000000
# 1     21.000000  1.520000   56.000000   3.0  3.0  3.000000  3.000000  0.000000
# 2     23.000000  1.800000   77.000000   2.0  3.0  2.000000  2.000000  1.000000
# 3     27.000000  1.800000   87.000000   3.0  3.0  2.000000  2.000000  0.000000
# 4     22.000000  1.780000   89.800000   2.0  1.0  2.000000  0.000000  0.000000
# ...         ...       ...         ...   ...  ...       ...       ...       ...
# 2106  20.976842  1.710730  131.408528   3.0  3.0  1.728139  1.676269  0.906247
# 2107  21.982942  1.748584  133.742943   3.0  3.0  2.005130  1.341390  0.599270
# 2108  22.524036  1.752206  133.689352   3.0  3.0  2.054193  1.414209  0.646288
# 2109  24.361936  1.739450  133.346641   3.0  3.0  2.852339  1.139107  0.586035
# 2110  23.664709  1.738836  133.472641   3.0  3.0  2.863513  1.026452  0.714137
#
# [2087 rows x 8 columns]

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df_obj.columns
for i in df_obj:
    df_obj[i]=le.fit_transform(df_obj[i])

# %%
df_obj
# Out:
#       Gender  family_history_with_overweight  FAVC  CAEC  SMOKE  SCC  CALC  \
# 0          0                               1     0     2      0    0     3
# 1          0                               1     0     2      1    1     2
# 2          1                               1     0     2      0    0     1
# 3          1                               0     0     2      0    0     1
# 4          1                               0     0     2      0    0     2
# ...      ...                             ...   ...   ...    ...  ...   ...
# 2106       0                               1     1     2      0    0     2
# 2107       0                               1     1     2      0    0     2
# 2108       0                               1     1     2      0    0     2
# 2109       0                               1     1     2      0    0     2
# 2110       0                               1     1     2      0    0     2
#
#       MTRANS  NObeyesdad
# 0          3           1
# ...

# %%
df_sum=pd.concat([df_num,df_obj],axis=1)
df_sum
# Out:
#             Age    Height      Weight  FCVC  NCP      CH2O       FAF  \
# 0     21.000000  1.620000   64.000000   2.0  3.0  2.000000  0.000000
# 1     21.000000  1.520000   56.000000   3.0  3.0  3.000000  3.000000
# 2     23.000000  1.800000   77.000000   2.0  3.0  2.000000  2.000000
# 3     27.000000  1.800000   87.000000   3.0  3.0  2.000000  2.000000
# 4     22.000000  1.780000   89.800000   2.0  1.0  2.000000  0.000000
# ...         ...       ...         ...   ...  ...       ...       ...
# 2106  20.976842  1.710730  131.408528   3.0  3.0  1.728139  1.676269
# 2107  21.982942  1.748584  133.742943   3.0  3.0  2.005130  1.341390
# 2108  22.524036  1.752206  133.689352   3.0  3.0  2.054193  1.414209
# 2109  24.361936  1.739450  133.346641   3.0  3.0  2.852339  1.139107
# 2110  23.664709  1.738836  133.472641   3.0  3.0  2.863513  1.026452
#
#            TUE  Gender  family_history_with_overweight  FAVC  CAEC  SMOKE  \
# ...

# %%
X=df_sum.drop('NObeyesdad',axis=1)
Y=df_sum['NObeyesdad']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.3,random_state=1)

# %%
X_train.shape
# Out:
# (1460, 16)

# %%
Y_train.shape
# Out:
# (1460,)

# %%
X_test.shape
# Out:
# (627, 16)

# %%
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()
X_train=ss.fit_transform(X_train)
X_test=ss.transform(X_test)

# %%
X_train
# Out:
# array([[ 0.2188414 , -0.83968086,  0.57060171, ..., -0.21411509,
#         -0.51695775,  0.52090182],
#        [ 0.58786075, -0.18959463,  0.46825021, ..., -0.21411509,
#          1.41831999,  0.52090182],
#        [ 1.49346069, -0.54219024, -0.38325554, ..., -0.21411509,
#          1.41831999, -1.8263718 ],
#        ...,
#        [-0.10708124,  0.30897937, -0.10110721, ..., -0.21411509,
#         -0.51695775,  0.52090182],
#        [-0.38085477, -1.0955936 , -0.8063395 , ..., -0.21411509,
#          1.41831999, -1.04394726],
#        [ 0.65318056, -0.03547452, -0.35031622, ..., -0.21411509,
#         -2.45223549, -1.8263718 ]])

# %%
#create a user define function :passing argument and returning  value
def create_model(model):
    model.fit(X_train,Y_train) #rtrain model with 70% of data
    y_pred=model.predict(X_test) #test the model with 30% of data
    #generate rport 
    print(classification_report(Y_test,y_pred))
#confusion matrix
    print(confusion_matrix(Y_test,y_pred))
    return model

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
# for i in range(1,101):
#     dtc=DecisionTreeClassifier(random_state=i)
#     print("random state",i)
#     dtc=create_model(dtc)

# %%
dtc=DecisionTreeClassifier(random_state=20)
dtc=create_model(dtc)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.92      0.92        85
#            1       0.84      0.84      0.84        90
#            2       0.95      0.94      0.95       101
#            3       0.95      0.97      0.96       100
#            4       0.99      1.00      0.99        86
#            5       0.87      0.90      0.88        80
#            6       0.98      0.93      0.95        85
#
#     accuracy                           0.93       627
#    macro avg       0.93      0.93      0.93       627
# weighted avg       0.93      0.93      0.93       627
#
# [[78  7  0  0  0  0  0]
#  [ 6 76  0  0  0  8  0]
#  [ 0  0 95  5  0  0  1]
#  [ 0  0  2 97  1  0  0]
#  [ 0  0  0  0 86  0  0]
#  [ 0  7  0  0  0 72  1]
#  [ 0  0  3  0  0  3 79]]

# %%
dict1={"columns":X.columns,'important features':dtc.feature_importances_}
df1=pd.DataFrame(dict1)
df1
# Out:
#                            columns  important features
# 0                              Age            0.024629
# 1                           Height            0.277747
# 2                           Weight            0.458866
# 3                             FCVC            0.013444
# 4                              NCP            0.011068
# 5                             CH2O            0.006776
# 6                              FAF            0.006231
# 7                              TUE            0.001201
# 8                           Gender            0.161061
# 9   family_history_with_overweight            0.002549
# 10                            FAVC            0.019701
# 11                            CAEC            0.011747
# 12                           SMOKE            0.000780
# 13                             SCC            0.000000
# 14                            CALC            0.001584
# 15                          MTRANS            0.002616

# %%
#max Depth
for i in range(1,9):
    dtc1=DecisionTreeClassifier(random_state=1,max_depth=i)
    print("random state",i)
    dtc1=create_model(dtc1)
# Out:
# random state 1
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        85
#            1       0.00      0.00      0.00        90
#            2       0.00      0.00      0.00       101
#            3       0.00      0.00      0.00       100
#            4       0.41      1.00      0.59        86
#            5       0.00      0.00      0.00        80
#            6       0.20      1.00      0.34        85
#
#     accuracy                           0.27       627
#    macro avg       0.09      0.29      0.13       627
# weighted avg       0.08      0.27      0.13       627
#
# [[ 0  0  0  0  0  0 85]
#  [ 0  0  0  0  0  0 90]
#  [ 0  0  0  0 28  0 73]
#  [ 0  0  0  0 94  0  6]
#  [ 0  0  0  0 86  0  0]
#  [ 0  0  0  0  0  0 80]
#  [ 0  0  0  0  0  0 85]]
# random state 2
#               precision    recall  f1-score   support
#
#            0       0.64      0.98      0.77        85
# ...

# %%
#min sample leaf
for i in range(1,45):
    dtc2=DecisionTreeClassifier(random_state=1,min_samples_leaf=i)
    print("random state",i)
    dtc2=create_model(dtc2)
# Out:
# random state 1
#               precision    recall  f1-score   support
#
#            0       0.92      0.92      0.92        85
#            1       0.81      0.86      0.83        90
#            2       0.94      0.94      0.94       101
#            3       0.95      0.97      0.96       100
#            4       0.99      1.00      0.99        86
#            5       0.89      0.85      0.87        80
#            6       0.98      0.93      0.95        85
#
#     accuracy                           0.93       627
#    macro avg       0.93      0.92      0.92       627
# weighted avg       0.93      0.93      0.93       627
#
# [[78  7  0  0  0  0  0]
#  [ 7 77  0  0  0  6  0]
#  [ 0  0 95  5  0  0  1]
#  [ 0  0  2 97  1  0  0]
#  [ 0  0  0  0 86  0  0]
#  [ 0 11  0  0  0 68  1]
#  [ 0  0  4  0  0  2 79]]
# random state 2
#               precision    recall  f1-score   support
#
#            0       0.93      0.93      0.93        85
# ...

# %%
dtc2=DecisionTreeClassifier(random_state=1,min_samples_leaf=3)
dtc2=create_model(dtc2)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.92      0.92        85
#            1       0.84      0.88      0.86        90
#            2       0.95      0.95      0.95       101
#            3       0.95      0.98      0.97       100
#            4       0.99      1.00      0.99        86
#            5       0.90      0.90      0.90        80
#            6       1.00      0.92      0.96        85
#
#     accuracy                           0.94       627
#    macro avg       0.94      0.93      0.94       627
# weighted avg       0.94      0.94      0.94       627
#
# [[78  7  0  0  0  0  0]
#  [ 6 79  0  0  0  5  0]
#  [ 0  0 96  5  0  0  0]
#  [ 0  0  1 98  1  0  0]
#  [ 0  0  0  0 86  0  0]
#  [ 0  8  0  0  0 72  0]
#  [ 0  0  4  0  0  3 78]]

# %%
from sklearn import tree
features=X.columns
plt.figure(figsize=(20,20))
_=tree.plot_tree(dtc2,feature_names=features,filled=True)

# %%
#max depth entropy
for i in range(1,9):
    dtc3=DecisionTreeClassifier(random_state=1,max_depth=i,criterion='entropy')
    print("max depth",i)
    dtc3=create_model(dtc3)
# Out:
# max depth 1
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        85
#            1       0.00      0.00      0.00        90
#            2       0.00      0.00      0.00       101
#            3       0.00      0.00      0.00       100
#            4       0.40      1.00      0.57        86
#            5       0.00      0.00      0.00        80
#            6       0.20      0.99      0.34        85
#
#     accuracy                           0.27       627
#    macro avg       0.09      0.28      0.13       627
# weighted avg       0.08      0.27      0.12       627
#
# [[ 0  0  0  0  0  0 85]
#  [ 0  0  0  0  0  0 90]
#  [ 0  0  0  0 31  0 70]
#  [ 0  0  0  0 99  0  1]
#  [ 0  0  0  0 86  0  0]
#  [ 0  0  0  0  0  0 80]
#  [ 0  0  0  0  1  0 84]]
# max depth 2
#               precision    recall  f1-score   support
#
#            0       0.64      0.98      0.77        85
# ...

# %%
for i in range(1,45):
    dtc3=DecisionTreeClassifier(random_state=1,min_samples_leaf=i,criterion='entropy')
    print("max depth",i)
    dtc3=create_model(dtc3)
# Out:
# max depth 1
#               precision    recall  f1-score   support
#
#            0       0.93      0.95      0.94        85
#            1       0.92      0.91      0.92        90
#            2       0.94      0.94      0.94       101
#            3       0.96      0.98      0.97       100
#            4       0.97      1.00      0.98        86
#            5       0.94      0.94      0.94        80
#            6       0.96      0.89      0.93        85
#
#     accuracy                           0.95       627
#    macro avg       0.95      0.95      0.95       627
# weighted avg       0.95      0.95      0.95       627
#
# [[81  4  0  0  0  0  0]
#  [ 6 82  0  0  0  2  0]
#  [ 0  0 95  4  1  0  1]
#  [ 0  0  0 98  2  0  0]
#  [ 0  0  0  0 86  0  0]
#  [ 0  3  0  0  0 75  2]
#  [ 0  0  6  0  0  3 76]]
# max depth 2
#               precision    recall  f1-score   support
#
#            0       0.90      0.95      0.93        85
# ...

# %%
dtc3=DecisionTreeClassifier(random_state=1,min_samples_leaf=1,criterion='entropy')
dtc3=create_model(dtc3) #best value
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.95      0.94        85
#            1       0.92      0.91      0.92        90
#            2       0.94      0.94      0.94       101
#            3       0.96      0.98      0.97       100
#            4       0.97      1.00      0.98        86
#            5       0.94      0.94      0.94        80
#            6       0.96      0.89      0.93        85
#
#     accuracy                           0.95       627
#    macro avg       0.95      0.95      0.95       627
# weighted avg       0.95      0.95      0.95       627
#
# [[81  4  0  0  0  0  0]
#  [ 6 82  0  0  0  2  0]
#  [ 0  0 95  4  1  0  1]
#  [ 0  0  0 98  2  0  0]
#  [ 0  0  0  0 86  0  0]
#  [ 0  3  0  0  0 75  2]
#  [ 0  0  6  0  0  3 76]]

# %%
#random forest Classifier
from sklearn.ensemble import RandomForestClassifier

# %%
# for i in range(1,17):
#     rfc=RandomForestClassifier(random_state=1,max_features=i)
#     print("max features",i)
#     rfc=create_model(rfc)

# %%
rfc=RandomForestClassifier(random_state=1,max_features=10)
rfc=create_model(rfc)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.96      0.97        85
#            1       0.93      0.94      0.94        90
#            2       0.96      0.99      0.98       101
#            3       0.99      0.98      0.98       100
#            4       0.99      1.00      0.99        86
#            5       0.96      0.96      0.96        80
#            6       0.99      0.95      0.97        85
#
#     accuracy                           0.97       627
#    macro avg       0.97      0.97      0.97       627
# weighted avg       0.97      0.97      0.97       627
#
# [[ 82   3   0   0   0   0   0]
#  [  2  85   0   0   0   2   1]
#  [  0   0 100   1   0   0   0]
#  [  0   0   1  98   1   0   0]
#  [  0   0   0   0  86   0   0]
#  [  0   3   0   0   0  77   0]
#  [  0   0   3   0   0   1  81]]

# %%
dict5={'Features':X.columns,"Information_Gain":rfc.feature_importances_}
df4=pd.DataFrame(dict5)
df4
#sorting values
df4=df4.sort_values(by='Information_Gain',ascending=False)
df4
# Out:
#                           Features  Information_Gain
# 2                           Weight          0.438526
# 1                           Height          0.175537
# 8                           Gender          0.096590
# 3                             FCVC          0.066090
# 0                              Age          0.065523
# 4                              NCP          0.024317
# 6                              FAF          0.022056
# 9   family_history_with_overweight          0.019340
# 5                             CH2O          0.018246
# 7                              TUE          0.018037
# 11                            CAEC          0.015282
# 10                            FAVC          0.014919
# 14                            CALC          0.013168
# 15                          MTRANS          0.007091
# 13                             SCC          0.003429
# 12                           SMOKE          0.001847

# %%
from sklearn.ensemble import AdaBoostClassifier

# %%
for i in range(1,17):
    ada=AdaBoostClassifier(random_state=1,n_estimators=i)
    print("n_estimators",i)
    ada=create_model(ada)
# Out:
# n_estimators 1
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        85
#            1       0.00      0.00      0.00        90
#            2       0.00      0.00      0.00       101
#            3       0.00      0.00      0.00       100
#            4       0.41      1.00      0.59        86
#            5       0.00      0.00      0.00        80
#            6       0.20      1.00      0.34        85
#
#     accuracy                           0.27       627
#    macro avg       0.09      0.29      0.13       627
# weighted avg       0.08      0.27      0.13       627
#
# [[ 0  0  0  0  0  0 85]
#  [ 0  0  0  0  0  0 90]
#  [ 0  0  0  0 28  0 73]
#  [ 0  0  0  0 94  0  6]
#  [ 0  0  0  0 86  0  0]
#  [ 0  0  0  0  0  0 80]
#  [ 0  0  0  0  0  0 85]]
# n_estimators 2
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        85
# ...

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
for i in range(10,101):
    gbc = GradientBoostingClassifier(n_estimators=i,random_state=1)
    print("No of estimators:",i)
    gbc=create_model(gbc)
# Out:
# No of estimators: 10
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98        85
#            1       0.80      0.83      0.82        90
#            2       0.84      0.82      0.83       101
#            3       0.97      0.96      0.96       100
#            4       1.00      1.00      1.00        86
#            5       0.73      0.71      0.72        80
#            6       0.72      0.73      0.73        85
#
#     accuracy                           0.86       627
#    macro avg       0.86      0.86      0.86       627
# weighted avg       0.86      0.86      0.86       627
#
# [[83  1  0  0  0  1  0]
#  [ 2 75  1  0  0 11  1]
#  [ 0  0 83  3  0  0 15]
#  [ 0  1  2 96  0  1  0]
#  [ 0  0  0  0 86  0  0]
#  [ 0 15  0  0  0 57  8]
#  [ 0  2 13  0  0  8 62]]
# No of estimators: 11
#               precision    recall  f1-score   support
#
#            0       0.98      0.96      0.97        85
# ...

# %%
gbc = GradientBoostingClassifier(n_estimators=98,random_state=1)
gbc=create_model(gbc)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99        85
#            1       0.95      0.97      0.96        90
#            2       0.95      0.97      0.96       101
#            3       0.98      0.99      0.99       100
#            4       1.00      1.00      1.00        86
#            5       0.96      0.94      0.95        80
#            6       0.98      0.94      0.96        85
#
#     accuracy                           0.97       627
#    macro avg       0.97      0.97      0.97       627
# weighted avg       0.97      0.97      0.97       627
#
# [[84  1  0  0  0  0  0]
#  [ 1 87  0  0  0  2  0]
#  [ 0  0 98  2  0  0  1]
#  [ 0  0  1 99  0  0  0]
#  [ 0  0  0  0 86  0  0]
#  [ 0  4  0  0  0 75  1]
#  [ 0  0  4  0  0  1 80]]

# %%
import xgboost as xgb

# %%
from xgboost import XGBClassifier

# %%
xgb=XGBClassifier()

# %%
for i in range(1,101):
    xgb=XGBClassifier(random_state=1,n_estimators=i)
    print("number",i)
    xgb=create_model(xgb)
# Out:
# number 1
#               precision    recall  f1-score   support
#
#            0       0.93      0.99      0.96        85
#            1       0.86      0.81      0.83        90
#            2       0.82      0.91      0.86       101
#            3       0.97      0.97      0.97       100
#            4       0.99      1.00      0.99        86
#            5       0.78      0.78      0.78        80
#            6       0.85      0.73      0.78        85
#
#     accuracy                           0.89       627
#    macro avg       0.89      0.88      0.88       627
# weighted avg       0.89      0.89      0.89       627
#
# [[84  0  1  0  0  0  0]
#  [ 6 73  1  0  0  8  2]
#  [ 0  0 92  3  0  1  5]
#  [ 0  0  1 97  1  1  0]
#  [ 0  0  0  0 86  0  0]
#  [ 0 11  3  0  0 62  4]
#  [ 0  1 14  0  0  8 62]]
# number 2
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98        85
#            1       0.88      0.84      0.86        90
# ...
